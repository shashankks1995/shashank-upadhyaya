# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_excel('E:data science\mavoix_ml_sample_dataset.xlsx')

# %%
df.head(50)
# Out:
#    Application_ID   Current City  Python (out of 3)  R Programming (out of 3)  \
# 0          ML0001      Bangalore                  0                         2
# 1          ML0002      Bangalore                  2                         0
# 2          ML0003      Bangalore                  3                         0
# 3          ML0004      Bangalore                  2                         0
# 4          ML0005      Bangalore                  2                         0
# 5          ML0006      Bangalore                  2                         0
# 6          ML0007      Bangalore                  1                         0
# 7          ML0008         Mumbai                  3                         1
# 8          ML0009      Bangalore                  3                         0
# 9          ML0010      Bangalore                  2                         0
# 10         ML0011      Bangalore                  2                         0
# ...

# %%
df.replace('',np.NaN,inplace=True)

# %% [markdown]
# ## checking for the null values

# %%
df.isnull().sum()
# Out:
# Application_ID                  0
# Current City                    0
# Python (out of 3)               0
# R Programming (out of 3)        0
# Deep Learning (out of 3)        0
# PHP (out of 3)                  0
# MySQL (out of 3)                0
# HTML (out of 3)                 0
# CSS (out of 3)                  0
# JavaScript (out of 3)           0
# Unnamed: 10                   392
# AJAX (out of 3)                 0
# Bootstrap (out of 3)            0
# MongoDB (out of 3)              0
# Node.js (out of 3)              0
# ReactJS (out of 3)              0
# Other skills                    0
# Degree                         12
# Stream                         18
# Current Year Of Graduation      0
# Performance_PG                289
# Performance_UG                 54
# Performance_12                163
# Performance_10                177
# dtype: int64

# %% [markdown]
# ## checking for the size of dataframe

# %%
df.shape
# Out:
# (392, 24)

# %%
177/392
# Out:
# 0.45153061224489793

# %%
14/392*100
# Out:
# 3.571428571428571

# %%
df.columns
# Out:
# Index(['Application_ID', 'Current City', 'Python (out of 3)',
#        'R Programming (out of 3)', 'Deep Learning (out of 3)',
#        'PHP (out of 3)', 'MySQL (out of 3)', 'HTML (out of 3)',
#        'CSS (out of 3)', 'JavaScript (out of 3)', 'Unnamed: 10',
#        'AJAX (out of 3)', 'Bootstrap (out of 3)', 'MongoDB (out of 3)',
#        'Node.js (out of 3)', 'ReactJS (out of 3)', 'Other skills', 'Degree',
#        'Stream', 'Current Year Of Graduation', 'Performance_PG',
#        'Performance_UG', 'Performance_12', 'Performance_10'],
#       dtype='object')

# %%
df.drop(columns='Unnamed: 10',inplace=True)

# %%
df.isnull().sum()
# Out:
# Application_ID                  0
# Current City                    0
# Python (out of 3)               0
# R Programming (out of 3)        0
# Deep Learning (out of 3)        0
# PHP (out of 3)                  0
# MySQL (out of 3)                0
# HTML (out of 3)                 0
# CSS (out of 3)                  0
# JavaScript (out of 3)           0
# AJAX (out of 3)                 0
# Bootstrap (out of 3)            0
# MongoDB (out of 3)              0
# Node.js (out of 3)              0
# ReactJS (out of 3)              0
# Other skills                    0
# Degree                         12
# Stream                         18
# Current Year Of Graduation      0
# Performance_PG                289
# Performance_UG                 54
# Performance_12                163
# Performance_10                177
# dtype: int64

# %%
df['Other skills'].describe()
# Out:
# count                                                   392
# unique                                                  313
# top       MS-Office, Python, Data Science, Machine Learn...
# freq                                                     15
# Name: Other skills, dtype: object

# %%
df['Other skills'].mode()
# Out:
# 0    MS-Office, Python, Data Science, Machine Learn...
# dtype: object

# %%
import statistics

# %% [markdown]
# ## the index with nan values in degree column

# %%
df[df['Degree'].isnull()]
# Out:
#     Application_ID Current City  Python (out of 3)  R Programming (out of 3)  \
# 5           ML0006    Bangalore                  2                         0
# 6           ML0007    Bangalore                  1                         0
# 12          ML0013    Hyderabad                  2                         2
# 52          ML0053    Hyderabad                  2                         0
# 64          ML0065    Bangalore                  2                         2
# 101         ML0102     Thrissur                  1                         2
# 117         ML0118    Hyderabad                  2                         2
# 137         ML0138    Bangalore                  2                         3
# 192         ML0193      Chennai                  2                         2
# 212         ML0213    Bangalore                  2                         0
# 247         ML0248    Bangalore                  0                         0
# ...

# %% [markdown]
# ## nan values in degree column is removed with mode of degree

# %%
statistics.mode(df['Degree'])
# Out:
# 'Bachelor of Technology (B.Tech)'

# %%
df['Degree'].fillna(value='Bachelor of Technology (B.Tech)',axis=0,inplace=True)

# %% [markdown]
# ## the index with nan values in stream column

# %%
df[df['Stream'].isnull()]
# Out:
#     Application_ID Current City  Python (out of 3)  R Programming (out of 3)  \
# 7           ML0008       Mumbai                  3                         1
# 24          ML0025      Lucknow                  2                         0
# 68          ML0069    Bangalore                  2                         0
# 72          ML0073    Bangalore                  2                         2
# 99          ML0100    Hyderabad                  2                         0
# 107         ML0108    Bangalore                  2                         0
# 128         ML0129     Banglore                  2                         0
# 151         ML0152    Bangalore                  1                         2
# 204         ML0205    Hyderabad                  2                         0
# 210         ML0211    Kozhikode                  0                         0
# 221         ML0222     Shillong                  0                         0
# ...

# %% [markdown]
# ## this also filled wth mode of that column

# %%
statistics.mode(df['Stream'])
# Out:
# 'Computer  Science'

# %%
df['Stream'].fillna(value='Computer  Science',axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Application_ID                  0
# Current City                    0
# Python (out of 3)               0
# R Programming (out of 3)        0
# Deep Learning (out of 3)        0
# PHP (out of 3)                  0
# MySQL (out of 3)                0
# HTML (out of 3)                 0
# CSS (out of 3)                  0
# JavaScript (out of 3)           0
# AJAX (out of 3)                 0
# Bootstrap (out of 3)            0
# MongoDB (out of 3)              0
# Node.js (out of 3)              0
# ReactJS (out of 3)              0
# Other skills                    0
# Degree                          0
# Stream                          0
# Current Year Of Graduation      0
# Performance_PG                289
# Performance_UG                 54
# Performance_12                163
# Performance_10                177
# dtype: int64

# %%
df[df['Performance_UG'].isnull()].head(50)
# Out:
#     Application_ID Current City  Python (out of 3)  R Programming (out of 3)  \
# 0           ML0001    Bangalore                  0                         2
# 20          ML0021     Thrissur                  1                         0
# 23          ML0024    Bangalore                  2                         0
# 55          ML0056    Raebareli                  2                         2
# 60          ML0061        Delhi                  3                         0
# 68          ML0069    Bangalore                  2                         0
# 70          ML0071    Bangalore                  3                         0
# 75          ML0076    Bangalore                  1                         0
# 81          ML0082    Bangalore                  3                         2
# 82          ML0083       Jaipur                  2                         0
# 84          ML0085    Bangalore                  2                         2
# ...

# %% [markdown]
# ## here Performance of 12th is in object format and it is convetred to Float and division operation is carried on and it is multiplied by 100 , to mke whole column in one scale

# %%
df[df['Performance_12'].isnull()].head()
# Out:
#    Application_ID Current City  Python (out of 3)  R Programming (out of 3)  \
# 0          ML0001    Bangalore                  0                         2
# 5          ML0006    Bangalore                  2                         0
# 7          ML0008       Mumbai                  3                         1
# 15         ML0016    Bangalore                  2                         0
# 16         ML0017    Kozhikode                  2                         0
#
#     Deep Learning (out of 3)  PHP (out of 3)  MySQL (out of 3)  \
# 0                          0               2                 0
# 5                          0               1                 0
# 7                          0               0                 0
# 15                         0               0                 2
# 16                         0               2                 0
#
#     HTML (out of 3)  CSS (out of 3)  JavaScript (out of 3)  ...  \
# ...

# %%
statistics.mode(df['Performance_12'])
# Out:
# nan

# %%
a=df['Performance_12']

# %%
a.dropna(inplace=True)

# %%
a
# Out:
# 1      92.20/92.20
# 2      64.83/64.83
# 3      76.00/76.00
# 4      65.20/65.20
# 6      85.00/85.00
#           ...
# 384    75.00/75.00
# 385      4.00/4.00
# 389    62.62/62.62
# 390    62.50/62.50
# 391    64.00/64.00
# Name: Performance_12, Length: 229, dtype: object

# %%
b=a.str.split('/',n=1,expand=True).astype(float)

# %%
b
# Out:
#          0      1
# 1    92.20  92.20
# 2    64.83  64.83
# 3    76.00  76.00
# 4    65.20  65.20
# 6    85.00  85.00
# ..     ...    ...
# 384  75.00  75.00
# 385   4.00   4.00
# 389  62.62  62.62
# 390  62.50  62.50
# 391  64.00  64.00
#
# [229 rows x 2 columns]

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 229 entries, 1 to 391
# Data columns (total 2 columns):
# 0    229 non-null float64
# 1    229 non-null float64
# dtypes: float64(2)
# memory usage: 5.4 KB

# %%
pd.to_numeric(b[0],downcast='float')
# Out:
# 1      92.199997
# 2      64.830002
# 3      76.000000
# 4      65.199997
# 6      85.000000
#          ...
# 384    75.000000
# 385     4.000000
# 389    62.619999
# 390    62.500000
# 391    64.000000
# Name: 0, Length: 229, dtype: float32

# %%
b['res']=b[0]/b[1]

# %%
b
# Out:
#          0      1  res
# 1    92.20  92.20  1.0
# 2    64.83  64.83  1.0
# 3    76.00  76.00  1.0
# 4    65.20  65.20  1.0
# 6    85.00  85.00  1.0
# ..     ...    ...  ...
# 384  75.00  75.00  1.0
# 385   4.00   4.00  1.0
# 389  62.62  62.62  1.0
# 390  62.50  62.50  1.0
# 391  64.00  64.00  1.0
#
# [229 rows x 3 columns]

# %% [markdown]
# ## here the performance column is in one scale

# %%
df['Performance_12']=b[0]

# %%
df.isnull().sum()
# Out:
# Application_ID                  0
# Current City                    0
# Python (out of 3)               0
# R Programming (out of 3)        0
# Deep Learning (out of 3)        0
# PHP (out of 3)                  0
# MySQL (out of 3)                0
# HTML (out of 3)                 0
# CSS (out of 3)                  0
# JavaScript (out of 3)           0
# AJAX (out of 3)                 0
# Bootstrap (out of 3)            0
# MongoDB (out of 3)              0
# Node.js (out of 3)              0
# ReactJS (out of 3)              0
# Other skills                    0
# Degree                          0
# Stream                          0
# Current Year Of Graduation      0
# Performance_PG                289
# Performance_UG                 54
# Performance_12                163
# Performance_10                177
# dtype: int64

# %%
aa=df['Performance_10']

# %% [markdown]
# ## performance_10 is assigned to aa

# %%
aa
# Out:
# 0              NaN
# 1      96.60/96.60
# 2      77.60/77.60
# 3      84.32/84.32
# 4      68.80/68.80
#           ...
# 387            NaN
# 388            NaN
# 389            NaN
# 390    76.50/76.50
# 391    64.60/64.60
# Name: Performance_10, Length: 392, dtype: object

# %% [markdown]
# ## SPLIT THE STRING AND CONVERTED TO FLOAT

# %%
ne=aa.str.split('/',n=1,expand=True).astype(float)

# %%
ne
# Out:
#          0      1
# 0      NaN    NaN
# 1    96.60  96.60
# 2    77.60  77.60
# 3    84.32  84.32
# 4    68.80  68.80
# ..     ...    ...
# 387    NaN    NaN
# 388    NaN    NaN
# 389    NaN    NaN
# 390  76.50  76.50
# 391  64.60  64.60
#
# [392 rows x 2 columns]

# %% [markdown]
# ## making all the column in one scale

# %%
df['Performance_10']=ne[0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 23 columns):
# Application_ID                392 non-null object
# Current City                  392 non-null object
# Python (out of 3)             392 non-null int64
# R Programming (out of 3)      392 non-null int64
# Deep Learning (out of 3)      392 non-null int64
# PHP (out of 3)                392 non-null int64
# MySQL (out of 3)              392 non-null int64
# HTML (out of 3)               392 non-null int64
# CSS (out of 3)                392 non-null int64
# JavaScript (out of 3)         392 non-null int64
# AJAX (out of 3)               392 non-null int64
# Bootstrap (out of 3)          392 non-null int64
# MongoDB (out of 3)            392 non-null int64
# Node.js (out of 3)            392 non-null int64
# ReactJS (out of 3)            392 non-null int64
# Other skills                  392 non-null object
# Degree                        392 non-null object
# ...

# %% [markdown]
# ## assigning performance_UG column to cc and converted to float

# %%
cc=df['Performance_UG']

# %%
cc_new=cc.str.split('/',n=1,expand=True).astype(float)

# %%
cc_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 2 columns):
# 0    338 non-null float64
# 1    338 non-null float64
# dtypes: float64(2)
# memory usage: 6.2 KB

# %% [markdown]
# ## and here division of nominator and denominator is carried on to find percentage of all student in column

# %%
cc_new['result']=(cc_new[0]/cc_new[1])*100

# %%
cc_new
# Out:
#          0      1  result
# 0      NaN    NaN     NaN
# 1    85.50  100.0   85.50
# 2    70.00  100.0   70.00
# 3     6.86   10.0   68.60
# 4     6.38   10.0   63.80
# ..     ...    ...     ...
# 387  75.00  100.0   75.00
# 388   6.80   10.0   68.00
# 389   6.10   10.0   61.00
# 390   6.50   10.0   65.00
# 391  63.06  100.0   63.06
#
# [392 rows x 3 columns]

# %%
df['Performance_UG']=cc_new['result']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 23 columns):
# Application_ID                392 non-null object
# Current City                  392 non-null object
# Python (out of 3)             392 non-null int64
# R Programming (out of 3)      392 non-null int64
# Deep Learning (out of 3)      392 non-null int64
# PHP (out of 3)                392 non-null int64
# MySQL (out of 3)              392 non-null int64
# HTML (out of 3)               392 non-null int64
# CSS (out of 3)                392 non-null int64
# JavaScript (out of 3)         392 non-null int64
# AJAX (out of 3)               392 non-null int64
# Bootstrap (out of 3)          392 non-null int64
# MongoDB (out of 3)            392 non-null int64
# Node.js (out of 3)            392 non-null int64
# ReactJS (out of 3)            392 non-null int64
# Other skills                  392 non-null object
# Degree                        392 non-null object
# ...

# %%
dd=df['Performance_PG']

# %%
dd_new=dd.str.split('/',n=1,expand=True).astype(float)

# %%
dd_new.head()
# Out:
#       0     1
# 0   NaN   NaN
# 1   NaN   NaN
# 2  7.91  10.0
# 3   NaN   NaN
# 4   NaN   NaN

# %%
dd_new['result']=dd_new[0]/dd_new[1]

# %%
dd_new.head()
# Out:
#       0     1  result
# 0   NaN   NaN     NaN
# 1   NaN   NaN     NaN
# 2  7.91  10.0   0.791
# 3   NaN   NaN     NaN
# 4   NaN   NaN     NaN

# %%
df['Performance_PG']=dd_new['result']

# %%
df['Performance_PG'].fillna(value=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Application_ID                  0
# Current City                    0
# Python (out of 3)               0
# R Programming (out of 3)        0
# Deep Learning (out of 3)        0
# PHP (out of 3)                  0
# MySQL (out of 3)                0
# HTML (out of 3)                 0
# CSS (out of 3)                  0
# JavaScript (out of 3)           0
# AJAX (out of 3)                 0
# Bootstrap (out of 3)            0
# MongoDB (out of 3)              0
# Node.js (out of 3)              0
# ReactJS (out of 3)              0
# Other skills                    0
# Degree                          0
# Stream                          0
# Current Year Of Graduation      0
# Performance_PG                  0
# Performance_UG                 54
# Performance_12                163
# Performance_10                177
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 23 columns):
# Application_ID                392 non-null object
# Current City                  392 non-null object
# Python (out of 3)             392 non-null int64
# R Programming (out of 3)      392 non-null int64
# Deep Learning (out of 3)      392 non-null int64
# PHP (out of 3)                392 non-null int64
# MySQL (out of 3)              392 non-null int64
# HTML (out of 3)               392 non-null int64
# CSS (out of 3)                392 non-null int64
# JavaScript (out of 3)         392 non-null int64
# AJAX (out of 3)               392 non-null int64
# Bootstrap (out of 3)          392 non-null int64
# MongoDB (out of 3)            392 non-null int64
# Node.js (out of 3)            392 non-null int64
# ReactJS (out of 3)            392 non-null int64
# Other skills                  392 non-null object
# Degree                        392 non-null object
# ...

# %%
df['Performance_UG'].isnull().sum()
# Out:
# 54

# %%
df['Current City'].unique()
# Out:
# array(['Bangalore', 'Mumbai', 'Jaipur', 'Hyderabad', 'Kozhikode',
#        'Chennai', 'Thrissur', 'Delhi', 'Lucknow', 'Visakhapatnam',
#        'Banglore', 'Dehradun', 'Nagpur', 'Dharwad', 'Bhubaneswar',
#        'Durgapur', 'Greater Noida', 'Pune', 'Raebareli', 'Meerut',
#        'Ernakulam', 'Indore', 'Ajmer', 'Chandigarh', 'Barhampur',
#        'Kolhapur', 'Idupulapaya', 'Jalandhar', 'Varanasi', 'Kolkata',
#        'Agartala', 'Vadodara', 'Ghaziabad', 'Kharagpur', 'Mangaluru',
#        'Roorkee', 'Coimbatore', 'Noida', 'Akola', 'Thane', 'Kochi',
#        'Nashik', 'Vellore', 'Agra', 'Shillong', 'Haryana', 'Tezpur',
#        'Mahé', 'Mysuru', 'Ranchi', 'Namakkal', 'Kannur', 'Kanpur',
#        'Guwahati', 'Tirupati', 'Walajapet', 'Durg', 'Raigarh',
#        'Jamshedpur', 'Vasco Da Gama', 'Tiruppur', 'Gorakhpur', 'Rudrapur'],
#       dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## from this graph it is clearly absorbed that most of the people applied from bangalore region

# %%
plt.figure(figsize=(20,15),)
sns.countplot(x='Current City',data=df)

# %%
df.isnull().sum()
# Out:
# Application_ID                  0
# Current City                    0
# Python (out of 3)               0
# R Programming (out of 3)        0
# Deep Learning (out of 3)        0
# PHP (out of 3)                  0
# MySQL (out of 3)                0
# HTML (out of 3)                 0
# CSS (out of 3)                  0
# JavaScript (out of 3)           0
# AJAX (out of 3)                 0
# Bootstrap (out of 3)            0
# MongoDB (out of 3)              0
# Node.js (out of 3)              0
# ReactJS (out of 3)              0
# Other skills                    0
# Degree                          0
# Stream                          0
# Current Year Of Graduation      0
# Performance_PG                  0
# Performance_UG                 54
# Performance_12                163
# Performance_10                177
# dtype: int64

# %%
train=df.drop(columns=df[['Performance_12','Performance_10']])

# %%
train.drop(columns='Application_ID',inplace=True)

# %% [markdown]
# ## here linear regression model is used to find the nan values in performance_ug

# %%
train['Current City']=enc.fit_transform(train['Current City'])
train['Other skills']=enc.fit_transform(train['Other skills'])
train['Degree']=enc.fit_transform(train['Degree'])
train['Stream']=enc.fit_transform(train['Stream'])

# %%
Xtrain=train[train['Performance_UG'].notnull()].drop(columns='Performance_UG')
ytrain=train[train['Performance_UG'].notnull()]['Performance_UG']

# %%
Xtest=train[train['Performance_UG'].isnull()].drop(columns='Performance_UG')

# %%
Xtest.isnull().sum()
# Out:
# Current City                  0
# Python (out of 3)             0
# R Programming (out of 3)      0
# Deep Learning (out of 3)      0
# PHP (out of 3)                0
# MySQL (out of 3)              0
# HTML (out of 3)               0
# CSS (out of 3)                0
# JavaScript (out of 3)         0
# AJAX (out of 3)               0
# Bootstrap (out of 3)          0
# MongoDB (out of 3)            0
# Node.js (out of 3)            0
# ReactJS (out of 3)            0
# Other skills                  0
# Degree                        0
# Stream                        0
# Current Year Of Graduation    0
# Performance_PG                0
# dtype: int64

# %%
ytest=train[train['Performance_UG'].isnull()]['Performance_UG']

# %%
from sklearn.linear_model import  LinearRegression
model=LinearRegression()

# %%
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 20 columns):
# Current City                  392 non-null int64
# Python (out of 3)             392 non-null int64
# R Programming (out of 3)      392 non-null int64
# Deep Learning (out of 3)      392 non-null int64
# PHP (out of 3)                392 non-null int64
# MySQL (out of 3)              392 non-null int64
# HTML (out of 3)               392 non-null int64
# CSS (out of 3)                392 non-null int64
# JavaScript (out of 3)         392 non-null int64
# AJAX (out of 3)               392 non-null int64
# Bootstrap (out of 3)          392 non-null int64
# MongoDB (out of 3)            392 non-null int64
# Node.js (out of 3)            392 non-null int64
# ReactJS (out of 3)            392 non-null int64
# Other skills                  392 non-null int64
# Degree                        392 non-null int64
# Stream                        392 non-null int64
# ...

# %%
model.fit(Xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pre=model.predict(Xtest)

# %%
train.Performance_UG[train.Performance_UG.isnull()]=pre
# Out:
# C:\Users\shash\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
train.isnull().sum()
# Out:
# Current City                  0
# Python (out of 3)             0
# R Programming (out of 3)      0
# Deep Learning (out of 3)      0
# PHP (out of 3)                0
# MySQL (out of 3)              0
# HTML (out of 3)               0
# CSS (out of 3)                0
# JavaScript (out of 3)         0
# AJAX (out of 3)               0
# Bootstrap (out of 3)          0
# MongoDB (out of 3)            0
# Node.js (out of 3)            0
# ReactJS (out of 3)            0
# Other skills                  0
# Degree                        0
# Stream                        0
# Current Year Of Graduation    0
# Performance_PG                0
# Performance_UG                0
# dtype: int64

# %%
train['Performance_UG']
# Out:
# 0      67.486374
# 1      85.500000
# 2      70.000000
# 3      68.600000
# 4      63.800000
#          ...
# 387    75.000000
# 388    68.000000
# 389    61.000000
# 390    65.000000
# 391    63.060000
# Name: Performance_UG, Length: 392, dtype: float64

# %%
df['Performance_UG']=train['Performance_UG']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 23 columns):
# Application_ID                392 non-null object
# Current City                  392 non-null object
# Python (out of 3)             392 non-null int64
# R Programming (out of 3)      392 non-null int64
# Deep Learning (out of 3)      392 non-null int64
# PHP (out of 3)                392 non-null int64
# MySQL (out of 3)              392 non-null int64
# HTML (out of 3)               392 non-null int64
# CSS (out of 3)                392 non-null int64
# JavaScript (out of 3)         392 non-null int64
# AJAX (out of 3)               392 non-null int64
# Bootstrap (out of 3)          392 non-null int64
# MongoDB (out of 3)            392 non-null int64
# Node.js (out of 3)            392 non-null int64
# ReactJS (out of 3)            392 non-null int64
# Other skills                  392 non-null object
# Degree                        392 non-null object
# ...

# %%
print(215/392)
print(229/392)
# Out:
# 0.548469387755102
# 0.5841836734693877

# %% [markdown]
#  ## as nearly 50% data is missing values in 10 and 12th performance hence it is deleted

# %%
df.drop(columns=df[['Performance_10','Performance_12']],inplace=True)

# %%
df.isnull().sum()
# Out:
# Application_ID                0
# Current City                  0
# Python (out of 3)             0
# R Programming (out of 3)      0
# Deep Learning (out of 3)      0
# PHP (out of 3)                0
# MySQL (out of 3)              0
# HTML (out of 3)               0
# CSS (out of 3)                0
# JavaScript (out of 3)         0
# AJAX (out of 3)               0
# Bootstrap (out of 3)          0
# MongoDB (out of 3)            0
# Node.js (out of 3)            0
# ReactJS (out of 3)            0
# Other skills                  0
# Degree                        0
# Stream                        0
# Current Year Of Graduation    0
# Performance_PG                0
# Performance_UG                0
# dtype: int64

# %% [markdown]
# ## Lebel encoding is carried on using sklearn.prepocessing using labelencoer

# %%
df['Current City']=enc.fit_transform(df['Current City'])
df['Other skills']=enc.fit_transform(df['Other skills'])
df['Degree']=enc.fit_transform(df['Degree'])
df['Stream']=enc.fit_transform(df['Stream'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 21 columns):
# Application_ID                392 non-null object
# Current City                  392 non-null int32
# Python (out of 3)             392 non-null int64
# R Programming (out of 3)      392 non-null int64
# Deep Learning (out of 3)      392 non-null int64
# PHP (out of 3)                392 non-null int64
# MySQL (out of 3)              392 non-null int64
# HTML (out of 3)               392 non-null int64
# CSS (out of 3)                392 non-null int64
# JavaScript (out of 3)         392 non-null int64
# AJAX (out of 3)               392 non-null int64
# Bootstrap (out of 3)          392 non-null int64
# MongoDB (out of 3)            392 non-null int64
# Node.js (out of 3)            392 non-null int64
# ReactJS (out of 3)            392 non-null int64
# Other skills                  392 non-null int32
# Degree                        392 non-null int32
# ...

# %%
from scipy import stats

# %%
new_data=df
new_data
# Out:
#     Application_ID  Current City  Python (out of 3)  R Programming (out of 3)  \
# 0           ML0001             4                  0                         2
# 1           ML0002             4                  2                         0
# 2           ML0003             4                  3                         0
# 3           ML0004             4                  2                         0
# 4           ML0005             4                  2                         0
# ..             ...           ...                ...                       ...
# 387         ML0388            22                  2                         1
# 388         ML0389             4                  2                         0
# 389         ML0390            41                  1                         0
# 390         ML0391            29                  2                         2
# 391         ML0392            15                  2                         3
#
# ...

# %%
new_data.drop(columns='Application_ID',inplace=True)

# %%
## before removing outlier

# %%
df.shape
# Out:
# (392, 20)

# %% [markdown]
# ## Outlier drection and removing from the dataset using zscore method

# %%
zsc = np.abs(stats.zscore(df))
new_data=new_data[(zsc<3).all(axis=1)]
new_data.shape ## after remoing outlier
# Out:
# (315, 20)

# %% [markdown]
# # to move ahead, this data is not enough for supervised machine learning modeling ,labelled data should be provided for that  and for clustering kind of thing it  is not sufficient data
